# %%
# !pip install bs4 requests
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=3918bd1a54338eec78d472229d702e9c92edfa0b62956528ed798bdf56c722a8
#   Stored in directory: c:\users\skander\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = requests.get('https://github.com/skanderzoghlami?tab=repositories')
url
# Out:
# <Response [200]>

# %%
source = BeautifulSoup(url.text, 'html.parser')
source
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
a = {}
for post in posts:
    if(post.find('p')):
        a[post.find('a').text[9:]] = post.find('p').text[9:]
    else :
        a[post.find('a').text[9:]] = "No description"

# %%
a
# Out:
# {'Projet-Covoiturage': '  This is the front end of A school project.\n        ',
#  'test-ci-cd': 'No description',
#  'J.A.R.V.I.S': 'No description',
#  'CS': '  Config files for my GitHub profile.\n        ',
#  'Deep-NN-for-image-generation': 'No description',
#  'Go-project': 'No description',
#  'NLP-Sentiment-Analysis-on-tunisian-words': '  Dataset used : https://zindi.africa/competitions/ai4d-icompass-social-media-sentiment-analysis-for-tunisian-arabizi/leaderboard?page=5\n        ',
#  'final-AR-app': 'No description',
#  'Machine-learning': 'No description',
#  'Messenger-Application-UI': '  This is the UI of the messenger application.\n        ',
#  'Super-Heroes-App': '  This is a mobile application created with flutter that allows the users to fetch data from Marvel databases aswell as star wars and star trek databases.\n        ',
# ...
